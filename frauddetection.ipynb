# %% [markdown]
# # Importing Libraries

# %%
import csv
import json
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import gridspec

# %% [markdown]
# # Data Loading

# %%
path = 'creditcard.csv'

# %%
creditcard = pd.read_csv(path)

# %%
creditcard
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# # Data Exploration

# %%
creditcard.info
# Out:
# <bound method DataFrame.info of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
creditcard.shape
# Out:
# (284807, 31)

# %%
creditcard.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
creditcard.describe
# Out:
# <bound method NDFrame.describe of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
missing_values = creditcard.isnull().sum()
print(missing_values)
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Data we are dealing with

# %%
fraud = creditcard[creditcard['Class'] == 1] 
valid = creditcard[creditcard['Class'] == 0] 
outlierFraction = len(fraud)/float(len(valid)) 
print(outlierFraction) 
print('Fraud Cases: {}'.format(len(creditcard[creditcard['Class'] == 1]))) 
print('Valid Transactions: {}'.format(len(creditcard[creditcard['Class'] == 0])))
# Out:
# 0.0017304750013189597
# Fraud Cases: 492
# Valid Transactions: 284315

# %%
print("Amount details of the fraudulent transaction")
fraud.Amount.describe()
# Out:
# Amount details of the fraudulent transaction
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
print("details of valid transaction")
valid.Amount.describe()
# Out:
# details of valid transaction
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# # Graphical Representation

# %%
corrmat = creditcard.corr() 
fig = plt.figure(figsize = (12, 9)) 
sns.heatmap(corrmat, vmax = .8, square = True) 
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Class', y='Amount', data=creditcard)
plt.title('Box Plot of Transaction Amounts for Genuine and Fraudulent Transactions')
plt.xlabel('Class (0: Genuine, 1: Fraudulent)')
plt.ylabel('Transaction Amount')
plt.show()

# %%
fraudulent_data = creditcard[creditcard['Class'] == 1]
plt.figure(figsize=(10, 6))
plt.scatter(fraudulent_data['Time'], fraudulent_data['Amount'], color='red', alpha=0.5)
plt.title('Scatter Plot of Fraudulent Transactions')
plt.xlabel('Time')
plt.ylabel('Transaction Amount')
plt.show()

# %%
creditcard['Time'] = pd.to_datetime(creditcard['Time'], unit='s')

# %%
fraudulent_counts = creditcard[creditcard['Class'] == 1].groupby('Time').size()
plt.figure(figsize=(14, 8))
fraudulent_counts.plot(style='o-', color='red')
plt.title('Time Series of Fraudulent Transactions')
plt.xlabel('Time')
plt.ylabel('Number of Fraudulent Transactions')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
creditcard['Hour'] = creditcard['Time'].dt.hour
creditcard['DayOfWeek'] = creditcard['Time'].dt.dayofweek
creditcard['IsWeekend'] = creditcard['DayOfWeek'].isin([5, 6]).astype(int)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
creditcard['Amount_Normalized'] = scaler.fit_transform(creditcard['Amount'].values.reshape(-1, 1))

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
creditcard[['PCA1', 'PCA2']] = pca.fit_transform(creditcard[['V1', 'V2', 'V3', 'V3', 'V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28']])

# %% [markdown]
# ## Separating x & y values

# %%
X = creditcard.drop(['Class'], axis = 1) 
Y = creditcard["Class"] 
print(X.shape) 
print(Y.shape)  
xData = X.values 
yData = Y.values
# Out:
# (284807, 36)
# (284807,)

# %% [markdown]
# ## Training & Testing Data

# %%
from sklearn.model_selection import train_test_split 
 
xTrain, xTest, yTrain, yTest = train_test_split( 
        xData, yData, test_size = 0.2, random_state = 42)

# %% [markdown]
# ## Evaluating the classifier

# %%
creditcard['Time'] = pd.to_numeric(creditcard['Time']) / 10**9

# %%
from sklearn.ensemble import RandomForestClassifier 

rfc = RandomForestClassifier() 
rfc.fit(xTrain, yTrain)
yPred = rfc.predict(xTest)

# %%
from sklearn.metrics import classification_report, accuracy_score 
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import f1_score, matthews_corrcoef 
from sklearn.metrics import confusion_matrix 

n_outliers = len(fraud) 
n_errors = (yPred != yTest).sum() 
print("The model used is Random Forest classifier") 

acc = accuracy_score(yTest, yPred) 
print("The accuracy is {}".format(acc)) 

prec = precision_score(yTest, yPred) 
print("The precision is {}".format(prec)) 

rec = recall_score(yTest, yPred) 
print("The recall is {}".format(rec)) 

f1 = f1_score(yTest, yPred) 
print("The F1-Score is {}".format(f1)) 

MCC = matthews_corrcoef(yTest, yPred) 
print("The Matthews correlation coefficient is{}".format(MCC))
# Out:
# The model used is Random Forest classifier
# The accuracy is 0.9995786664794073
# The precision is 0.9868421052631579
# The recall is 0.7653061224489796
# The F1-Score is 0.8620689655172413
# The Matthews correlation coefficient is0.8688552993136148

# %%
LABELS = ['Normal', 'Fraud'] 
conf_matrix = confusion_matrix(yTest, yPred) 
plt.figure(figsize =(12, 12)) 
sns.heatmap(conf_matrix, xticklabels = LABELS,  
            yticklabels = LABELS, annot = True, fmt ="d"); 
plt.title("Confusion matrix") 
plt.ylabel('True class') 
plt.xlabel('Predicted class') 
plt.show()
